# %%
"""importation des bibliothèques/modules"""


import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio,display
from scipy.io import wavfile


RATE = 44100
LA = 440
DO = 523.25

""" Questions : 
1) Pour échantilloner un son de 440Hz, il faut 44100 échantillons par seconde (le RATE)
2)  position = A*sin(2*np.pi*phi*t), avec A l'amplitude de la vibration 
"""
#3)

"""
abscisses = np.linspace(0,1,RATE) 
ordonnées = np.sin(2*np.pi*LA*abscisses)

plt.plot(abscisses, ordonnées)
#plt.show()

display(Audio(ordonnées,rate=RATE))
"""
#4) 
t = np.linspace(0,1,RATE) #les points à mettre dans la fonction
def display_signal(signal, rate=RATE, title="Signal", width=1) : #signal à échantilloner/fréquance d'échantillonage
    abs = np.linspace(0,1,rate)
    plt.plot(abs, signal)
    plt.show()
    display(Audio(signal,rate=RATE))

display_signal(np.sin(2*np.pi*t))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#2.2
RATE =44100

def sine(freq, rate=RATE,duration=1,amplitude=1) : #on met des valeurs défauts si on a pas la donnée
    abs = np.linspace(0,1,rate)
    ord = np.sin(2*np.pi*freq*abs)
    plt.plot(abs, ord)
    plt.show()
    display(Audio(ord,rate=RATE) )

sine(440)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#2.3
RATE = 44100
def sine_linear(freq1,freq2,duration=1,amplitude=1) :
    varfreq =np.linspace(freq1,freq2,RATE)
    abs = np.linspace(0,1,RATE)
    ord = np.sin(2*np.pi*varfreq*abs+ ) # on ajoute la phase pour ne pas avoir de décalage 
    plt.plot(abs, ord)
    plt.show()
    display(Audio(ord,rate=RATE) )

sine_linear(440,523,3)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#3
#Pour moduler l'amplitude de la sinusoïde, on
